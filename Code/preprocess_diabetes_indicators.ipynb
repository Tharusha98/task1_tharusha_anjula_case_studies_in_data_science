# %% [markdown]
# # Preprocess - CDC Diabetes Health Indicators
#
# TODO: clean and scale features from `Dataset/diabetes-indicators/diabetes_binary_health_indicators_BRFSS2015.csv`; save to `Dataset/processed/diabetes_indicators_clean.csv`.
