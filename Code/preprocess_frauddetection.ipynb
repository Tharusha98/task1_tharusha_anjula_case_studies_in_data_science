# %% [markdown]
# # Preprocess - Simulated Fraud Detection
#
# TODO: clean `Dataset/fraud-detection/fraudTrain.csv` and `fraudTest.csv`, save to `Dataset/processed/frauddetection_train_clean.csv` and `frauddetection_test_clean.csv`.
