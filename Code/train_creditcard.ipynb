# %% [markdown]
# # Train - Credit Card Fraud (ULB)
#
# TODO: train Logistic Regression and Random Forest models on `Dataset/processed/creditcard_clean.csv`; save plots/metrics to `Code/outputs/creditcard/`.
