# %% [markdown]
# # Train - Simulated Fraud Detection
#
# TODO: train Logistic Regression and Random Forest models on `Dataset/processed/frauddetection_train_clean.csv`; evaluate on `frauddetection_test_clean.csv`; save plots/metrics to `Code/outputs/frauddetection/`.
